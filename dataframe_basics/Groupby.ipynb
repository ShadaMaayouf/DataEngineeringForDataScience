# %% [markdown]
# # ```Groupby```
#
# Groupby is a pretty simple concept. We can create a grouping of categories and apply a function to the categories. It’s a simple concept but it’s an extremely valuable technique that’s widely used in data science. In real data science projects, you’ll be dealing with large amounts of data and trying things over and over, so for efficiency, we use Groupby concept. Groupby concept is really important because it’s ability to aggregate data efficiently, both in performance and the amount code is magnificent. Groupby mainly refers to a process involving one or more of the following steps they are:
# * **Splitting** : It is a process in which we split data into group by applying some conditions on datasets.
# * Applying : It is a process in which we apply a function to each group independently
# * **Combining** : It is a process in which we combine different datasets after applying groupby and results into a data structure
# The following image will help in understanding a process involve in Groupby concept.
#
# The following image will help in understanding a process involve in Groupby concept.
#
# 1. Group the unique values from the Team column:
# ![image.png](attachment:image.png)
# 2. Now there’s a bucket for each group:
# ![image-2.png](attachment:image-2.png)
# 3. Toss the other data into the buckets:
# ![image-3.png](attachment:image-3.png)
# 4. Apply a function on the weight column of each bucket:
# ![image-4.png](attachment:image-4.png)
#
# ### Splitting Data into Groups
# Splitting is a process in which we split data into a group by applying some conditions on datasets. In order to split the data, we apply certain conditions on datasets. In order to split the data, we use groupby() function this function is used to split the data into groups based on some criteria. Pandas objects can be split on any of their axes. The abstract definition of grouping is to provide a mapping of labels to group names. Pandas datasets can be split into any of their objects. There are multiple ways to split data like:
# * ```obj.groupby(key)```
# * ```obj.groupby(key, axis=1)```
# * ```obj.groupby([key1, key2])```

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv("./data/employees_satisfaction_transformed.csv", index_col=0)
df
# Out:
#      age  department     education    recruitment_type  job_level
# 0     28          HR  Postgraduate            Referral          5  \
# 1     50  Technology  Postgraduate  Recruitment Agency          3
# 2     43  Technology     Undergrad            Referral          4
# 3     44       Sales  Postgraduate           On-Campus          2
# 4     33          HR     Undergrad  Recruitment Agency          2
# ..   ...         ...           ...                 ...        ...
# 495   49          HR  Postgraduate           On-Campus          2
# 496   24  Technology     Undergrad            Referral          2
# 497   34   Marketing  Postgraduate           On-Campus          1
# 498   26  Technology     Undergrad             Walk-in          2
# 499   26  Technology     Undergrad  Recruitment Agency          3
#
#           rating  awards  certifications   salary  gender  entry_date
# 0            2.0       1               0  78075.0    Male  2019-02-01  \
# 1            5.0       2               1  38177.1    Male  2017-01-17
# 2            1.0       2               0  59143.5  Female  2012-08-27
# 3            3.0       0               0  26824.5  Female  2017-07-25
# 4            1.0       5               0  26824.5    Male  2019-05-17
# ..           ...     ...             ...      ...     ...         ...
# 495          5.0       6               0  26824.5    Male  2014-03-21
# 496          4.0       2               0  26824.5  Female  2018-02-20
# 497  Unavailable       2               0  21668.4    Male  2020-10-20
# 498          1.0       1               1  26824.5    Male  2012-05-18
# 499          4.0       3               0  38177.1    Male  2018-12-28
#
#      satisfied
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1
# ..         ...
# 495          1
# 496          0
# 497          1
# 498          0
# 499          0
#
# [500 rows x 12 columns]

# %% [markdown]
# # 1. grouping with one key: ```groupby(key)```
# In order to group data with one key, we pass only one key as an argument in groupby function.

# %% [markdown]
# #### get specific group.

# %%
group.get_group('HR')
# Out:
#      age department     education    recruitment_type  job_level rating
# 0     28         HR  Postgraduate            Referral          5    2.0  \
# 4     33         HR     Undergrad  Recruitment Agency          2    1.0
# 8     35         HR  Postgraduate            Referral          3    4.0
# 18    54         HR  Postgraduate           On-Campus          1    5.0
# 20    35         HR     Undergrad           On-Campus          2    4.0
# ..   ...        ...           ...                 ...        ...    ...
# 484   34         HR  Postgraduate             Walk-in          2    5.0
# 486   54         HR  Postgraduate  Recruitment Agency          4    3.0
# 489   33         HR     Undergrad           On-Campus          2    1.0
# 492   33         HR     Undergrad           On-Campus          3    5.0
# 495   49         HR  Postgraduate           On-Campus          2    5.0
#
#      awards  certifications   salary  gender  entry_date  satisfied
# 0         1               0  78075.0    Male  2019-02-01          1
# 4         5               0  26824.5    Male  2019-05-17          1
# 8         0               0  38177.1  Female  2015-04-02          1
# 18        4               0  21668.4  Female  2014-05-07          1
# 20        4               0  26824.5  Female  2008-01-15          1
# ..      ...             ...      ...     ...         ...        ...
# 484       7               1  26824.5  Female  2013-01-14          1
# 486       2               0  59143.5    Male  2015-08-09          1
# 489       7               0  26824.5  Female  2016-09-03          1
# 492       6               1  38177.1    Male  2017-08-09          1
# 495       6               0  26824.5    Male  2014-03-21          1
#
# [106 rows x 12 columns]

# %% [markdown]
# #### Print first entry in each group

# %%
group.first()
# Out:
#             age     education    recruitment_type  job_level rating  awards
# department
# HR           28  Postgraduate            Referral          5    2.0       1  \
# Marketing    31     Undergrad             Walk-in          4    4.0       6
# Purchasing   40     Undergrad             Walk-in          3    3.0       7
# Sales        44  Postgraduate           On-Campus          2    3.0       0
# Technology   50  Postgraduate  Recruitment Agency          3    5.0       2
#
#             certifications   salary  gender  entry_date  satisfied
# department
# HR                       0  78075.0    Male  2019-02-01          1
# Marketing                0  59143.5    Male  2009-01-24          1
# Purchasing               1  38177.1    Male  2004-04-22          1
# Sales                    0  26824.5  Female  2017-07-25          1
# Technology               1  38177.1    Male  2017-01-17          0

# %% [markdown]
# # 2. grouping with multiple keys: ```groupby([key1, key2])```

# %%
group2 = df.groupby(['department', 'gender'])
group2.size()

# To reach 59 in HR -> Female is equivalent to len(group2.get_group(('HR', 'Female')))
# Out:
# department  gender
# HR          Female     59
#             Male       46
#             Unknown     1
# Marketing   Female     40
#             Male       54
#             Unknown     1
# Purchasing  Female     47
#             Male       67
# Sales       Female     42
#             Male       45
# Technology  Female     45
#             Male       52
#             Unknown     1
# dtype: int64

# %%
group2.groups
# Out:
# {('HR', 'Female'): [8, 18, 20, 47, 51, 67, 70, 74, 91, 94, 95, 96, 115, 116, 118, 125, 127, 129, 147, 153, 169, 185, 196, 212, 229, 231, 235, 249, 272, 276, 277, 280, 284, 289, 302, 303, 308, 320, 336, 357, 361, 373, 388, 391, 396, 397, 398, 399, 414, 415, 419, 426, 457, 467, 473, 480, 481, 484, 489], ('HR', 'Male'): [0, 4, 21, 42, 43, 
# Out:
#      age department     education    recruitment_type  job_level       rating
# 8     35         HR  Postgraduate            Referral          3          4.0  \
# 18    54         HR  Postgraduate           On-Campus          1          5.0
# 20    35         HR     Undergrad           On-Campus          2          4.0
# 47    46         HR     Undergrad            Referral          3          2.0
# 51    42         HR     Undergrad           On-Campus          1          1.0
# 67    28         HR  Postgraduate            Referral          1  Unavailable
# 70    30         HR     Undergrad  Recruitment Agency          1  Unavailable
# 74    46         HR  Postgraduate            Referral          5          1.0
# 91    36         HR     Undergrad  Recruitment Agency          3          2.0
# 94    36         HR     Undergrad             Walk-in          1          1.0
# 95    44         HR     Undergrad            Referral          4          4.0
# 96    33         HR     Undergrad  Recruitment Agency          4          5.0
# 115   37         HR     Undergrad            Referral          4          3.0
# 116   25         HR     Undergrad            Referral          2          4.0
# 118   28         HR  Postgraduate  Recruitment Agency          1          3.0
# 125   35         HR  Postgraduate  Recruitment Agency          1          2.0
# 127   37         HR  Postgraduate  Recruitment Agency          4          1.0
# 129   42         HR  Postgraduate            Referral          4          1.0
# 147   41         HR     Undergrad            Referral          4          5.0
# 153   41         HR     Undergrad  Recruitment Agency          2          1.0
# 169   46         HR     Undergrad            Referral          3          3.0
# 185   47         HR  Postgraduate             Walk-in          1          2.0
# 196   37         HR     Undergrad           On-Campus          3          5.0
# 212   44         HR     Undergrad           On-Campus          1          4.0
# 229   38         HR     Undergrad           On-Campus          1          2.0
# 231   34         HR  Postgraduate             Walk-in          5          4.0
# 235   53         HR  Postgraduate             Walk-in          4          5.0
# 249   47         HR     Undergrad            Referral          3          2.0
# 272   35         HR     Undergrad            Referral          3          3.0
# 276   22         HR  Postgraduate  Recruitment Agency          1          4.0
# 277   54         HR  Postgraduate           On-Campus          2          2.0
# 280   53         HR  Postgraduate  Recruitment Agency          4          3.0
# 284   27         HR     Undergrad            Referral          4          1.0
# 289   53         HR  Postgraduate           On-Campus          5          4.0
# 302   54         HR     Undergrad  Recruitment Agency          5          1.0
# 303   52         HR     Undergrad           On-Campus          4          2.0
# 308   41         HR  Postgraduate            Referral          2          2.0
# 320   48         HR     Undergrad            Referral          2          3.0
# 336   30         HR     Undergrad            Referral          5          2.0
# 357   28         HR  Postgraduate  Recruitment Agency          3  Unavailable
# 361   25         HR     Undergrad           On-Campus          1  Unavailable
# 373   38         HR  Postgraduate  Recruitment Agency          2          3.0
# 388   46         HR  Postgraduate            Referral          1  Unavailable
# 391   50         HR  Postgraduate             Walk-in          4          3.0
# 396   45         HR     Undergrad  Recruitment Agency          5          1.0
# 397   36         HR     Undergrad  Recruitment Agency          4          5.0
# 398   46         HR  Postgraduate  Recruitment Agency          3  Unavailable
# 399   52         HR     Undergrad            Referral          5          1.0
# 414   41         HR     Undergrad             Walk-in          1          1.0
# 415   43         HR  Postgraduate           On-Campus          2          1.0
# 419   44         HR     Undergrad            Referral          5          2.0
# 426   32         HR     Undergrad  Recruitment Agency          3          2.0
# 457   40         HR  Postgraduate             Walk-in          1          4.0
# 467       0               1  38177.1  Female  2016-08-16          0
# 473       4               0  78075.0  Female  2009-07-13          0
# 480       3               1  59143.5  Female  2008-04-09          1
# 481       3               0  59143.5  Female  2008-09-08          0
# 484       7               1  26824.5  Female  2013-01-14          1
# 489       7               0  26824.5  Female  2016-09-03          1

# %% [markdown]
# **Beispiel** : In welcher Abteilung sind die meisten zufriedenen Angestellten?

# %%
satisfied = df[df['satisfied'] == 1]
satisfied['department'].value_counts()
#or
satisfied.groupby('department')['satisfied'].sum()
# Out:
# department
# HR            73
# Marketing     61
# Purchasing    80
# Sales         70
# Technology    73
# Name: satisfied, dtype: int64

# %% [markdown]
# # 2. grouping based on date and Time:
#
# ## 2.1. using groupby
#
# **Verändert sich das Recruiting über die Jahre?**
#
# Erstellen Sie hierzu ein Liniendiagramm, das die Anzahl der Angestellten über die Zeit (entry_date) in Abhängigkeit vom Recruitment-Typ darstellt.

# %%
df['entry_date'] = pd.to_datetime(df['entry_date'], format='%Y-%m-%d')

# %%
df.groupby([df["entry_date"].dt.year, df["recruitment_type"]]).size()
# Out:
# entry_date  recruitment_type
# 2004        On-Campus              6
#             Recruitment Agency     1
#             Referral               6
#             Walk-in               15
# 2005        On-Campus              5
#                                   ..
# 2019        Walk-in                1
# 2020        On-Campus              8
#             Recruitment Agency    12
#             Referral               8
#             Walk-in                1
# Length: 68, dtype: int64

# %% [markdown]
# ## 2.2. using ```pd.Grouper()```

# %%
df.groupby(pd.Grouper(key='entry_date', axis=0, freq='Y')).size()
# Out:
# entry_date
# 2004-12-31    28
# 2005-12-31    29
# 2006-12-31    27
# 2007-12-31    34
# 2008-12-31    34
# 2009-12-31    31
# 2010-12-31    25
# 2011-12-31    20
# 2012-12-31    24
# 2013-12-31    30
# 2014-12-31    38
# 2015-12-31    28
# 2016-12-31    34
# 2017-12-31    23
# 2018-12-31    30
# 2019-12-31    36
# 2020-12-31    29
# Freq: A-DEC, dtype: int64

# %% [markdown]
# ## 3. Functions of groupby

# %% [markdown]
# ### 3.1. ```sum()```

# %%
df.groupby(['department'])['awards'].sum()
# Out:
# department
# HR            465
# Marketing     407
# Purchasing    531
# Sales         396
# Technology    486
# Name: awards, dtype: int64

# %% [markdown]
# ### 3.2. sort and ```sort()```
# Group keys are sorted by default using the groupby operation. User can pass ```sort=False``` for potential speedups.

# %%
df.groupby(['department'], sort = False)['awards'].sum()
# Out:
# department
# HR            465
# Technology    486
# Sales         396
# Purchasing    531
# Marketing     407
# Name: awards, dtype: int64

# %% [markdown]
# ### 3.3. iterating through groups

# %%
grp = df.groupby('department')
for name, group in grp:
    print(name)
    print(group)
    print()
# Out:
# HR
#      age department     education    recruitment_type  job_level rating
# 0     28         HR  Postgraduate            Referral          5    2.0  \
# 4     33         HR     Undergrad  Recruitment Agency          2    1.0
# 8     35         HR  Postgraduate            Referral          3    4.0
# 18    54         HR  Postgraduate           On-Campus          1    5.0
# 20    35         HR     Undergrad           On-Campus          2    4.0
# ..   ...        ...           ...                 ...        ...    ...
# 484   34         HR  Postgraduate             Walk-in          2    5.0
# 486   54         HR  Postgraduate  Recruitment Agency          4    3.0
# 489   33         HR     Undergrad           On-Campus          2    1.0
# 492   33         HR     Undergrad           On-Campus          3    5.0
# 495   49         HR  Postgraduate           On-Campus          2    5.0
#
#      awards  certifications   salary  gender  entry_date  satisfied
# 0         1               0  78075.0    Male  2019-02-01          1
# 4         5               0  26824.5    Male  2019-05-17          1
# 8         0               0  38177.1  Female  2015-04-02          1
# 18        4               0  21668.4  Female  2014-05-07          1
# 20        4               0  26824.5  Female  2008-01-15          1
# ..      ...             ...      ...     ...         ...        ...
# 484       7               1  26824.5  Female  2013-01-14          1
# 486       2               0  59143.5    Male  2015-08-09          1
# 489       7               0  26824.5  Female  2016-09-03          1
# 492       6               1  38177.1    Male  2017-08-09          1
# 495       6               0  26824.5    Male  2014-03-21          1
#
# [106 rows x 12 columns]
#
# Marketing
#      age department     education    recruitment_type  job_level       rating
# 10    31  Marketing     Undergrad             Walk-in          4          4.0  \
# 16    34  Marketing  Postgraduate           On-Campus          1          4.0
# 26    45  Marketing     Undergrad             Walk-in          4          3.0
# 29    38  Marketing     Undergrad            Referral          2          5.0
# 32    49  Marketing  Postgraduate           On-Campus          1          2.0
# ..   ...        ...           ...                 ...        ...          ...
# 471   48  Marketing  Postgraduate           On-Campus          5          4.0
# 474   44  Marketing     Undergrad  Recruitment Agency          2          5.0
# 482   38  Marketing  Postgraduate             Walk-in          5          2.0
# 493   41  Marketing     Undergrad             Walk-in          5          4.0
# 497   34  Marketing  Postgraduate           On-Campus          1  Unavailable
#
#      awards  certifications   salary  gender  entry_date  satisfied
# 10        6               0  59143.5    Male  2009-01-24          1
# 16        9               0  21668.4    Male  2014-12-10          0
# 26        8               0  59143.5    Male  2008-01-08          1
# 29        2               0  26824.5    Male  2008-06-03          1
# 32        9               0  21668.4    Male  2011-03-06          1
# ..      ...             ...      ...     ...         ...        ...
# 471       4               1  78075.0    Male  2019-10-26          1
# 474       5               0  26824.5  Female  2017-01-25          1
# 482       6               0  78075.0  Female  2004-09-16          1
# 493       2               0  78075.0    Male  2005-07-22          0
# 497       2               0  21668.4    Male  2020-10-20          1
#
# [95 rows x 12 columns]
#
# Purchasing
#      age  department     education    recruitment_type  job_level
# 5     40  Purchasing     Undergrad             Walk-in          3  \
# 6     26  Purchasing     Undergrad            Referral          5
# 13    48  Purchasing  Postgraduate            Referral          3
# 14    52  Purchasing  Postgraduate  Recruitment Agency          5
# 15    50  Purchasing     Undergrad  Recruitment Agency          5
# ..   ...         ...           ...                 ...        ...
# 476   39  Purchasing     Undergrad           On-Campus          1
# 477   45  Purchasing     Undergrad  Recruitment Agency          4
# 483   27  Purchasing  Postgraduate  Recruitment Agency          4
# 485   47  Purchasing     Undergrad  Recruitment Agency          5
# 490   47  Purchasing     Undergrad  Recruitment Agency          4
#
#           rating  awards  certifications   salary  gender  entry_date
# 5            3.0       7               1  38177.1    Male  2004-04-22  \
# 6            5.0       2               0  78075.0    Male  2019-12-10
# 13           4.0       8               0  38177.1    Male  2010-07-25
# 14           1.0       7               0  78075.0    Male  2018-02-07
# 15           5.0       6               0  78075.0    Male  2014-04-24
# ..           ...     ...             ...      ...     ...         ...
# 476          1.0       2               0  21668.4    Male  2010-11-08
# 477          2.0       2               0  59143.5  Female  2013-07-26
# 483  Unavailable       1               0  59143.5  Female  2020-07-22
# 485          3.0       5               1  78075.0    Male  2019-01-06
# 490          4.0       6               1  59143.5  Female  2019-10-17
#
#      satisfied
# 5            1
# 6            1
# 13           1
# 14           1
# 15           1
# ..         ...
# 476          1
# 477          0
# 483          0
# 485          1
# 490          0
#
# [114 rows x 12 columns]
#
# Sales
#      age department     education    recruitment_type  job_level rating
# 3     44      Sales  Postgraduate           On-Campus          2    3.0  \
# 19    25      Sales     Undergrad  Recruitment Agency          5    4.0
# 23    37      Sales     Undergrad  Recruitment Agency          5    5.0
# 24    31      Sales  Postgraduate             Walk-in          4    4.0
# 25    53      Sales  Postgraduate             Walk-in          4    5.0
# ..   ...        ...           ...                 ...        ...    ...
# 462   31      Sales     Undergrad  Recruitment Agency          4    2.0
# 468   39      Sales  Postgraduate           On-Campus          1    4.0
# 479   40      Sales  Postgraduate            Referral          4    4.0
# 488   50      Sales     Undergrad           On-Campus          3    3.0
# 494   31      Sales  Postgraduate            Referral          3    3.0
#
#      awards  certifications   salary  gender  entry_date  satisfied
# 3         0               0  26824.5  Female  2017-07-25          1
# 19        4               0  78075.0    Male  2012-02-15          1
# 23        0               1  78075.0    Male  2016-03-22          1
# 24        3               1  59143.5  Female  2006-09-05          1
# 25        8               1  59143.5  Female  2005-10-08          1
# ..      ...             ...      ...     ...         ...        ...
# 462       3               1  59143.5  Female  2013-01-14          0
# 468       0               1  21668.4    Male  2012-02-07          1
# 479       8               1  59143.5  Female  2017-04-13          0
# 488       4               0  38177.1    Male  2019-06-26          0
# 494       1               0  38177.1  Female  2006-03-29          1
#
# [87 rows x 12 columns]
#
# Technology
#      age  department     education    recruitment_type  job_level
# 1     50  Technology  Postgraduate  Recruitment Agency          3  \
# 2     43  Technology     Undergrad            Referral          4
# 7     25  Technology     Undergrad  Recruitment Agency          1
# 9     45  Technology  Postgraduate            Referral          3
# 11    43  Technology  Postgraduate  Recruitment Agency          2
# ..   ...         ...           ...                 ...        ...
# 487   51  Technology     Undergrad           On-Campus          5
# 491   23  Technology  Postgraduate           On-Campus          3
# 496   24  Technology     Undergrad            Referral          2
# 498   26  Technology     Undergrad             Walk-in          2
# 499   26  Technology     Undergrad  Recruitment Agency          3
#
#           rating  awards  certifications   salary  gender  entry_date
# 1            5.0       2               1  38177.1    Male  2017-01-17  \
# 2            1.0       2               0  59143.5  Female  2012-08-27
# 7            1.0       4               0  21668.4  Female  2017-03-18
# 9            3.0       9               0  38177.1  Female  2004-03-19
# 11           1.0       9               1  26824.5    Male  2016-03-10
# ..           ...     ...             ...      ...     ...         ...
# 487  Unavailable       8               0  78075.0    Male  2020-02-25
# 491          1.0       7               0  38177.1  Female  2015-05-05
# 496          4.0       2               0  26824.5  Female  2018-02-20
# 498          1.0       1               1  26824.5    Male  2012-05-18
# 499          4.0       3               0  38177.1    Male  2018-12-28
#
#      satisfied
# 1            0
# 2            1
# 7            0
# 9            0
# 11           1
# ..         ...
# 487          1
# 491          1
# 496          0
# 498          0
# 499          0
#
# [98 rows x 12 columns]

# %% [markdown]
# ## Applying function to group
#
# After splitting a data into a group, we apply a function to each group in order to do that we perform some operation they are:
# * **Aggregation** : It is a process in which we compute a summary statistic (or statistics) about each group. For Example, Compute group sums ormeans. Aggregated function returns a single aggregated value for each group. After splitting a data into groups using groupby function, several aggregation operations can be performed on the grouped data.
#
# * **Transformation** : It is a process in which we perform some group-specific computations and return a like-indexed. For Example, Filling NAs within groups with a value derived from each group
# * **Filtration** : It is a process in which we discard some groups, according to a group-wise computation that evaluates True or False. For Example, Filtering out data based on the group sum or mean
#
# ### 1. Aggregation
#
# #### using ```aggregate()```
# **Code #1**: Using aggregation via the aggregate method

# %%
grp1 = df.groupby('department')
grp1['awards'].aggregate(sum) # or grp1['awards'].aggregate(np.sum)
# Out:
# department
# HR            465
# Marketing     407
# Purchasing    531
# Sales         396
# Technology    486
# Name: awards, dtype: int64

# %% [markdown]
# #### Applying multiple functions to the same column :
# We can apply a multiple functions at once by passing a list or dictionary of functions to do aggregation with, outputting a DataFrame.

# %%
#grp['awards'].agg([sum, mean, std)

# %% [markdown]
# #### Applying different functions to different columns :
# In order to apply a different aggregation to the columns of a DataFrame, we can pass a dictionary to aggregate .

# %%
grp1.agg({'age' : 'sum', 'awards' : 'std'})
# Out:
#              age    awards
# department
# HR          4173  2.731024
# Marketing   3698  3.030565
# Purchasing  4576  2.706364
# Sales       3377  2.975710
# Technology  4023  3.514091

# %% [markdown]
# ### 2. Transformation :
# Transformation is a process in which we perform some group-specific computations and return a like-indexed. Transform method returns an object that is indexed the same (same size) as the one being grouped. The transform function must:
# * Return a result that is either the same size as the group chunk
# * Operate column-by-column on the group chunk
# * Not perform in-place operations on the group chunk.
#
# #### 2.1. perform group-specific computations and return a like-indexed.

# %%
# using transform function
grp3 = df.groupby('department')['awards']
sc = lambda x: (x - x.mean()) / x.std()*10
grp3.transform(sc)
# Out:
# 0     -12.401183
# 1      -8.420909
# 2      -8.420909
# 3     -15.296261
# 4       2.245340
#          ...
# 495     5.906970
# 496    -8.420909
# 497    -7.537244
# 498   -11.266596
# 499    -5.575223
# Name: awards, Length: 500, dtype: float64

# %% [markdown]
# ### 3. Filtration :
# Filtration is a process in which we discard some groups, according to a group-wise computation that evaluates True or False. In order to filter a group, we use filter method and apply some condition by which we filter group.

# %%
grp = df.groupby('department')['awards']
grp.filter(lambda x: len(x) >= 2)
# Out:
# 0      1
# 1      2
# 2      2
# 3      0
# 4      5
#       ..
# 495    6
# 496    2
# 497    2
# 498    1
# 499    3
# Name: awards, Length: 500, dtype: int64
